# %%
import requests

def get_most_popular_articles(n, year, month, day):
    """
    Fetches the top N most popular articles on Wikipedia for a given date,
    excluding special pages like 'Special:Search'.
    """
    url = f"https://wikimedia.org/api/rest_v1/metrics/pageviews/top/en.wikipedia/all-access/{year}/{month}/{day}"
    headers = {
        'User-Agent': 'WikiSandbox/ManagingBigData'  # Replace with your project and email
    }
    response = requests.get(url, headers=headers)
    
    if response.status_code != 200:
        raise Exception(f"Error fetching top articles: {response.status_code}")
    
    data = response.json()
    # Filter out 'Main_Page' and 'Special:' entries
    articles = [
        (article['article'], article['views'])
        for article in data['items'][0]['articles']
        if not article['article'].startswith("Special:") and article['article'] != "Main_Page"
    ]
    return articles[:n]


def get_article_text(title):
    """
    Fetches the full text of a Wikipedia article.
    """
    title = title.replace(" ", "_")  # Replace spaces with underscores for API compatibility
    url = f"https://en.wikipedia.org/api/rest_v1/page/summary/{title}"
    headers = {
        'User-Agent': 'WikiSandbox/ManagingBigData'  # Replace with your project and email
    }
    response = requests.get(url, headers=headers)
    
    if response.status_code == 404:
        return f"No content available for {title}. (404 Error)"
    elif response.status_code != 200:
        raise Exception(f"Error fetching article {title}: {response.status_code}")
    
    data = response.json()
    return data.get('extract', 'No content available')

def main():
    n = 1000  # Number of top articles to fetch
    year, month, day = "2024", "05", "01"  # Year, Month, and Day for the date
    
    print(f"Fetching the top {n} articles on Wikipedia for {year}-{month}-{day}...")
    popular_articles = get_most_popular_articles(n, year, month, day)
    
    for idx, (title, views) in enumerate(popular_articles, start=1):
        print(f"\n#{idx}: {title} ({views} views)")
        print("Fetching article text...")
        text = get_article_text(title)
        print(f"Summary: {text[:500]}..." if text else "Summary: No content available")

if __name__ == "__main__":
    main()
# Out:
# Fetching the top 1000 articles on Wikipedia for 2024-05-01...
#
# #1: International_Workers'_Day (553048 views)
# Fetching article text...
# Summary: International Workers' Day, also known as Labour Day in some countries and often referred to as May Day, is a celebration of labourers and the working classes that is promoted by the international labour movement and occurs every year on 1 May, or the first Monday in May....
#
# #2: Labour_Day (463629 views)
# Fetching article text...
# Summary: Labour Day is an annual day of celebration of the achievements of workers. It has its origins in the labour union movement, specifically the eight-hour day movement, which advocated eight hours for work, eight hours for recreation, and eight hours for rest....
#
# #3: Indian_Premier_League (350581 views)
# Fetching article text...
# Summary: The Indian Premier League, also known as IPL and Tata IPL for sponsorship reasons, is a men's T20 cricket league held annually in India. Founded by the BCCI in 2007, the league features ten state or city-based franchise teams. It is the most popular and richest cricket league in the world and its seasons usually take place between March and May. It has an exclusive window in the ICC Future Tours Programme, resulting in fewer international cricket tours occurring during the IPL seasons....
#
# #4: Wikipedia:Featured_pictures (336335 views)
# Fetching article text...
# Summary: No content available
#
# #5: Meena_Alexander (318837 views)
# Fetching article text...
# Summary: Meena Alexander was an Indian American poet, scholar, and writer. Born in Allahabad, India, and raised in India and Sudan, Alexander later lived and worked in New York City, where she was a Distinguished Professor of English at Hunter College and the CUNY Graduate Center....
#
# #6: Pornhub (214958 views)
# Fetching article text...
# Summary: Pornhub is a Canadian-owned internet pornography video-sharing website, one of several owned by adult entertainment conglomerate Aylo. As of August 2024, Pornhub is the 16th-most-visited website in the world and the most-visited adult website....

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 60
#      57         print(f"Summary: {text[:500]}..." if text else "Summary: No content available")
#      59 if __name__ == "__main__":
# ---> 60     main()
#
# Cell In[2], line 56, in main()
#      54 print(f"\n#{idx}: {title} ({views} views)")
#      55 print("Fetching article text...")
# ---> 56 text = get_article_text(title)
#      57 print(f"Summary: {text[:500]}..." if text else "Summary: No content available")
#
# Cell In[2], line 36, in get_article_text(title)
#      32 url = f"https://en.wikipedia.org/api/rest_v1/page/summary/{title}"
#      33 headers = {
#      34     'User-Agent': 'WikiSandbox/ManagingBigData'  # Replace with your project and email
#      35 }
# ---> 36 response = requests.get(url, headers=headers)
#      38 if response.status_code == 404:
#      39     return f"No content available for {title}. (404 Error)"
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/urllib3/connection.py:704, in HTTPSConnection.connect(self)
#     702 try:
#     703     sock: socket.socket | ssl.SSLSocket
# --> 704     self.sock = sock = self._new_conn()
#     705     server_hostname: str = self.host
#     706     tls_in_tls = False
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     193 """Establish a socket connection and set nodelay settings on it.
#     194
#     195 :return: New socket connection.
#     196 """
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#     205     raise NameResolutionError(self.host, self, e) from e
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %%
import requests

def get_full_article(title):
    """
    Fetches the full content of a Wikipedia article in wikitext format.
    """
    title = title.replace(" ", "_")  # Replace spaces with underscores for API compatibility
    url = f"https://en.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "prop": "revisions",
        "rvslots": "*",
        "rvprop": "content",
        "format": "json",
        "titles": title
    }
    headers = {
        'User-Agent': 'WikiSandbox/ManagingBigData'  # Replace with your project info
    }
    
    response = requests.get(url, headers=headers, params=params)
    
    if response.status_code != 200:
        raise Exception(f"Error fetching article {title}: {response.status_code}")
    
    data = response.json()
    pages = data["query"]["pages"]
    page = next(iter(pages.values()))  # Get the first page
    if "revisions" not in page:
        return f"No content available for {title}."
    
    return page["revisions"][0]["slots"]["main"]["*"]

def main():
    article_title = "Artificial intelligence"
    print(f"Fetching full article for: {article_title}")
    content = get_full_article(article_title)
    print(content[:1000])  # Print the first 1000 characters of the article
    #print(content)  # Print the first 1000 characters of the article


if __name__ == "__main__":
    main()

# %% [markdown]
# Most popular 20k articles

# %%
import requests
import time

def get_most_popular_articles(n, year, month, day):
    """
    Fetches the top N most popular articles on Wikipedia for a given date.
    """
    url = f"https://wikimedia.org/api/rest_v1/metrics/pageviews/top/en.wikipedia/all-access/{year}/{month}/{day}"
    headers = {
        'User-Agent': 'WikiSandbox/ManagingBigData'  # Replace with your project and email
    }
    response = requests.get(url, headers=headers)
    
    if response.status_code != 200:
        raise Exception(f"Error fetching top articles: {response.status_code}")
    
    data = response.json()
    articles = data['items'][0]['articles'][:n]
    return [(article['article'], article['views']) for article in articles if not article['article'].startswith("Special:") and article['article'] != "Main_Page"]

# %%
import requests
import time
import json
import os

def get_most_popular_articles(n, year, month, day):
    """
    Fetches the top N most popular articles on Wikipedia for a given date.
    """
    url = f"https://wikimedia.org/api/rest_v1/metrics/pageviews/top/en.wikipedia/all-access/{year}/{month}/{day}"
    headers = {
        'User-Agent': 'WikiSandbox/ManagingBigData'  # Replace with your project and email
    }
    response = requests.get(url, headers=headers)
    
    if response.status_code != 200:
        raise Exception(f"Error fetching top articles: {response.status_code}")
    
    data = response.json()
    articles = data['items'][0]['articles'][:n]
    return [(article['article'], article['views']) for article in articles if not article['article'].startswith("Special:") and article['article'] != "Main_Page"]

def fetch_articles_in_batches(titles_batch):
    """
    Fetches up to 50 articles in a single API call.
    """
    url = "https://en.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "prop": "revisions",
        "rvslots": "*",
        "rvprop": "content",
        "format": "json",
        "titles": "|".join(titles_batch)  # Batch up to 50 titles
    }
    headers = {"User-Agent": "WikiSandbox/ManagingBigData"}
    response = requests.get(url, headers=headers, params=params)
    if response.status_code != 200:
        raise Exception(f"Error fetching articles: {response.status_code}")
    return response.json()

def save_to_hdfs(data, file_path):
    """
    Saves the data to a file formatted for HDFS ingestion.
    """
    os.makedirs(os.path.dirname(file_path), exist_ok=True)
    with open(file_path, "a", encoding="utf-8") as f:
        for article in data:
            json.dump(article, f, ensure_ascii=False)
            f.write("\n")  # Write each article as a separate JSON line

def main():
    n = 20000  # Number of top articles to fetch
    year, month, day = "2024", "10", "01"
    output_file = "hdfs_data/wikipedia_articles"+year+month+day+".jsonl"
    total_saved = 0  # Track the total number of articles saved
    
    print(f"Fetching the top {n} articles on Wikipedia for {year}-{month}-{day}...")
    popular_articles = get_most_popular_articles(n, year, month, day)
    print(len(popular_articles))
    all_titles = [title for title, views in popular_articles]
    all_titles = correctTitles
    batch_size = 50  # Max 50 titles per batch
    batches = [all_titles[i:i + batch_size] for i in range(0, len(all_titles), batch_size)]
    
    for idx, batch in enumerate(batches, start=1):
        print(f"Fetching batch {idx}/{len(batches)}...")
        try:
            data = fetch_articles_in_batches(batch)
            processed_data = []
            for page_id, page_info in data["query"]["pages"].items():
                title = page_info["title"]
                if "revisions" in page_info:
                    text = page_info["revisions"][0]["slots"]["main"]["*"]
                else:
                    text = "No content available"
                processed_data.append({"title": title, "text": text})
            save_to_hdfs(processed_data, output_file)
            total_saved += len(processed_data)
        except Exception as e:
            print(f"Failed to fetch batch {idx}: {e}")
        time.sleep(1)  # Wait 1 second between batches

    print(f"Total articles saved: {total_saved}")

if __name__ == "__main__":
    main()
# Out:
# Fetching the top 20000 articles on Wikipedia for 2024-10-01...
# 995
# Fetching batch 1/10...
# Fetching batch 2/10...
# Fetching batch 3/10...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 87
#      84     print(f"Total articles saved: {total_saved}")
#      86 if __name__ == "__main__":
# ---> 87     main()
#
# Cell In[30], line 69, in main()
#      67 print(f"Fetching batch {idx}/{len(batches)}...")
#      68 try:
# ---> 69     data = fetch_articles_in_batches(batch)
#      70     processed_data = []
#      71     for page_id, page_info in data["query"]["pages"].items():
#
# Cell In[30], line 37, in fetch_articles_in_batches(titles_batch)
#      28 params = {
#      29     "action": "query",
#      30     "prop": "revisions",
#    (...)
#      34     "titles": "|".join(titles_batch)  # Batch up to 50 titles
#      35 }
#      36 headers = {"User-Agent": "WikiSandbox/ManagingBigData"}
# ---> 37 response = requests.get(url, headers=headers, params=params)
#      38 if response.status_code != 200:
#      39     raise Exception(f"Error fetching articles: {response.status_code}")
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Getting revisions

# %%
import requests
import time
import json
import os

def get_article_revisions(title, older_than=None):
    """
    Fetches revisions for a given article.
    """
    url = f'https://api.wikimedia.org/core/v1/wikipedia/en/page/{title}/history'
    parameters = {}
    if older_than:
        parameters['older_than'] = older_than
    headers = {
        'User-Agent': 'WikiSandbox/ManagingBigData'  # Replace with your project and email
    }
    response = requests.get(url, headers=headers, params=parameters)
    if response.status_code != 200:
        raise Exception(f"Error fetching revisions for {title}: {response.status_code}")
    data = response.json()
    return data.get("revisions", [])

def loop_through_revisions(title, from_date=None, olderThanId=None):
    """
    Loops through revisions for an article until a specific timestamp is reached.
    """
    revisions = []
    while True:
        new_revisions = get_article_revisions(title, older_than=olderThanId)
        if not new_revisions:
            break
        revisions.extend(new_revisions)
        if new_revisions[-1]["timestamp"] <= from_date:
            break
        olderThanId = new_revisions[-1]["id"]
    print(f"Gathered {len(revisions)} revisions for article: {title}")
    return revisions

def get_revision_count(title):
    """
    Fetches the total revision count for an article.
    """
    url = f'https://api.wikimedia.org/core/v1/wikipedia/en/page/{title}/history/counts/edits'
    headers = {
        'User-Agent': 'WikiSandbox/ManagingBigData'  # Replace with your project and email
    }
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        raise Exception(f"Error fetching revision count for {title}: {response.status_code}")
    print(response.json())
    return response.json()

def save_revisions_to_hdfs(revisions, filename):
    """
    Saves the revisions in an HDFS-compatible format (JSON Lines).
    """
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    with open(filename, "a", encoding="utf-8") as f:
        for revision in revisions:
            json.dump(revision, f, ensure_ascii=False)
            f.write("\n")  # Each revision is a separate JSON line

def compare_revisions(rev1, rev2):
    url = 'https://api.wikimedia.org/core/v1/wikipedia/en/revision/' + rev1 + '/compare/' + rev2
    headers = {
        'User-Agent': 'WikiSandbox/ManagingBigData'  # Replace with your project and email
    }
    response = requests.get(url, headers=headers)
    print(response.json())
    if response.status_code != 200:
        raise Exception(f"Error fetching revision comparison: {response.status_code}")
    return response.json()
def main():
    n = 1  # Number of top articles to fetch
    year, month, day = "2024", "05", "01"
    revisions_from = "2024-04-30T13:16:57Z"
    output_dir = "hdfs_data"
    print(f"Fetching the top {n} articles on Wikipedia for {year}-{month}-{day}...")
    
    # Use your existing `get_most_popular_articles` function
    popular_articles = get_most_popular_articles(n, year, month, day)
    
    for idx, (title, views) in enumerate(popular_articles, start=1):
        print(f"\n#{idx}: {title} ({views} views)")
        
        # Fetch revision count
        revs = get_revision_count(title)
        print(f"Total revisions: {revs['count']}")

        # Fetch revisions
        print(f"Fetching article revisions... after {revisions_from}")
        revisions = loop_through_revisions(title, from_date=revisions_from)
        print(revisions[0])
        print(revisions[1])
        # Save revisions to HDFS-compatible format
        compare_revisions("1265626085","1261527387")
        output_file = os.path.join(output_dir, f"{title}_revisions.jsonl")
        save_revisions_to_hdfs(revisions, output_file)
        print(f"Revisions saved to: {output_file}")

if __name__ == "__main__":
    main()
# Out:
# Fetching the top 1 articles on Wikipedia for 2024-05-01...
#
# #1: International_Workers'_Day (553048 views)
# {'count': 2674, 'limit': False}
# Total revisions: 2674
# Fetching article revisions... after 2024-04-30T13:16:57Z
# Gathered 100 revisions for article: International_Workers'_Day
# {'id': 1265626085, 'timestamp': '2024-12-27T21:28:51Z', 'minor': False, 'size': 178623, 'comment': '/* Singapore */', 'user': {'id': 46117955, 'name': 'Karttapelimies'}, 'delta': 10}
'====Haiti====', 'offset': 47572}, {'level': 4, 'heading': '====Honduras====', 'offset': 47962}, {'level': 4, 'heading': '====Mexico====', 'offset': 48359}, {'level': 4, 'heading': '====Panama====', 'offset': 48491}, {'level': 4, 'heading': '====Paraguay====', 'offset': 48856}, {'level': 4, 'heading': '====Peru====', 'offset': 49255}, {'level': 4, 'heading': '====Saint Kitts and Nevis====', 'offset': 49854}, {'level': 4, 'heading': '====United States====', 'offset': 50164}, {'level': 4, 'heading': '====Uruguay====', 'offset': 60813}, {'level': 4, 'heading': '====Venezuela====', 'offset': 61141}, {'level': 3, 'heading': '===East Asia===', 'offset': 61789}, {'level': 4, 'heading': '==== Mainland China ====', 'offset': 61806}, {'level': 4, 'heading': '==== Hong Kong ====', 'offset': 64855}, {'level': 4, 'heading': '==== Macau ====', 'offset': 65795}, {'level': 4, 'heading': '====Taiwan====', 'offset': 66284}, { ...
# Revisions saved to: hdfs_data/International_Workers'_Day_revisions.jsonl

# %%
import requests

S = requests.Session()

URL = "https://en.wikipedia.org/w/api.php"

cats = [
    "Category:Russo-Ukrainian War",
    "Category:2010s conflicts",
    "Category:2020s conflicts",
    "Category:2010s in Russia",
    "Category:2010s in Ukraine",
    "Category:2020s in Russia",
    "Category:2020s in Ukraine",
    "Category:Conflicts in Ukraine",
    "Category:Invasions by Russia",
    "Category:Invasions of Ukraine",
    "Category:Wars involving Russia",
    "Category:Wars involving Ukraine",
    "Category:Conflicts in territory of the former Soviet Union",
    "Category:Russia–Ukraine military relations",
    "Category:Russian irredentism",
    "Category:Vladimir Putin",
    "Category:Petro Poroshenko",
    "Category:Volodymyr Zelenskyy",
    "Category:21st-century military history of Russia",
    "Category:21st-century military history of Ukraine"
]
articleTitles = []
for category in cats:
    PARAMS = {
        "action": "query",
        "cmtitle": category,
        "cmlimit": "100",
        "list": "categorymembers",
        "format": "json"
    }

    R = S.get(url=URL, params=PARAMS)
    DATA = R.json()

    PAGES = DATA['query']['categorymembers']
    print(len(PAGES))
    
    for page in PAGES:
        articleTitles.append(page['title'])
        print(page['title'])
print(len(set(articleTitles)))
#if the title contains "Category: drop it"

correctTitles = [tit for tit in set(articleTitles) if not tit.startswith("Category:")]

# Print or use the filtered list
print(correctTitles)
# Out:
# 91
# Russo-Ukrainian War
# Annexation of Crimea by the Russian Federation
# Russian invasion of Ukraine
# War in Donbas
# Outline of the Russo-Ukrainian War
# 2014 pro-Russian unrest in Ukraine
# 2015 Ukraine power grid hack
# 2024 visits by Viktor Orbán to Russia and China
# Anti-Maidan
# Best in Hell
# Book of Remembrance for Those Who Fell for Ukraine
# Bridges in the Russo-Ukrainian War
# Confiscation of Russian central bank funds
# Crimean consensus
# Croatia and the Russo-Ukrainian War
# 2017 Ukraine ransomware attacks
# Environmental impact of the Russian occupation of Crimea
# European Deterrence Initiative
# Georgia and the Russian invasion of Ukraine
# Humanitarian impacts of the Russian invasion of Ukraine
# Humanitarian situation during the war in Donbas
# Hydraulic warfare
# Intermarium (region)
# International recognition of the Donetsk People's Republic and the Luhansk People's Republic
# International sanctions during the Russian invasion of Ukraine
# Iran–Israel proxy conflict
# Iran–PJAK conflict
# Iraq War
# War in Iraq (2013–2017)
# Iraqi conflict
# Iraqi insurgency (2003–2011)
# Islamic State insurgency in Iraq (2017–present)
# Iraqi insurgency (2011–2013)
# Islamic State affiliated terrorist attacks in France
# Islamic State in Jammu and Kashmir
# Islamic State insurgency in Puntland
# Islamic State–Taliban conflict
# Islamist insurgency in the Sahel
# Israel–PKK conflict
# Ituri conflict
# Jalisco Cartel New Generation-Los Caballeros Templarios Cartel War
# Joint Operation Nuevo León-Tamaulipas
# Kivu conflict
# Kurdistan Region–PKK conflict
# Libyan civil war (2014–2020)
# Libyan crisis (2011–present)
# Insurgency in the Maghreb (2002–present)
# Mali War
# Maoist insurgency in Bangladesh
# Mapuche conflict
# Mexican drug war
# Armed conflict for control of the favelas
# Nagorno-Karabakh conflict
# Naxalite–Maoist insurgency
# Nigerian bandit conflict
# Papua conflict
# Pemon conflict
# Qatar–Saudi Arabia diplomatic conflict
# Qatif conflict
# Russo-Caucasian conflict
# Russo-Ukrainian War
# Saudi-led intervention in the Yemeni civil war
# Sinai insurgency
# Sistan and Baluchestan insurgency
# Somali Civil War (2009–present)
# Ethnic violence in South Sudan
# South Sudanese Civil War
# South Thailand insurgency
# Sudanese conflict in South Kordofan and Blue Nile
# Taliban insurgency
# Timeline of the Moro conflict
# Transnistria conflict
# History of the War in Afghanistan (2001–2021)
# War in Afghanistan (2001–2021)
# War on terror
# Whisky War
# Yemeni crisis
# Category:2010s military operations
# Category:War in Afghanistan (2001–2021)
# Category:Anglophone Crisis
# Category:Arab Spring
# Category:Arab Winter
# Category:Attacks in the 2010s
# Category:Basque conflict
# Category:Boko Haram insurgency
# Category:Insurgency in Cabo Delgado
# Category:2010s civil wars
# Category:Conflicts in 2010
# Category:Conflicts in 2011
# Category:Conflicts in 2012
# Category:Conflicts in 2013
# Category:Conflicts in 2014
# Category:Conflicts in 2015
# Category:Conflicts in 2016
# 100
# Afar–Somali clashes
# Afghanistan–Pakistan border conflicts
# Allied Democratic Forces insurgency
# Anglophone Crisis
# Cabinda War
# Corsican conflict
# 2021–2024 Democratic Republic of the Congo attacks
# Gaza–Israel conflict
# Herder–farmer conflicts in Nigeria
# Houthi insurgency
# Houthi–Saudi Arabian conflict
# Humanitarian aid in conflict zones
# Insurgency in Bahrain
# Insurgency in Cabo Delgado
# Insurgency in Khyber Pakhtunkhwa
# Insurgency in Paraguay
# Internal conflict in Peru
# Iran–Israel conflict during the Syrian civil war
# Iran–Israel proxy conflict
# Iraqi conflict
# Islamic State insurgency in Iraq (2017–present)
# Islamic State in Jammu and Kashmir
# Islamic State insurgency in Puntland
# Islamic State–Taliban conflict
# Islamist insurgency in the Sahel
# Israel–Hamas war
# Israel–Hezbollah conflict (2023–present)
# Israel–PKK conflict
# Ituri conflict
# JNIM-ISGS war
# Kivu conflict
# Kurdistan Region–PKK conflict
# Libyan civil war (2014–2020)
# Libyan crisis (2011–present)
# Insurgency in the Maghreb (2002–present)
# Mali War
# Maoist insurgency in Bangladesh
# Mapuche conflict
# Middle Eastern crisis (2023–present)
# Armed conflict for control of the favelas
# Naxalite–Maoist insurgency
# Nigerian bandit conflict
# Palestinian Authority–West Bank militias conflict
# Papua conflict
# Pemon conflict
# Qatar–Saudi Arabia diplomatic conflict
# Qatif conflict
# Red Sea crisis
# Russian invasion of Ukraine
# Russo-Ukrainian War
# Saudi-led intervention in the Yemeni civil war
# Operation Shujaa
# Sistan and Baluchestan insurgency
# Somali Civil War (2009–present)
# South Thailand insurgency
# Sudanese civil war (2023–present)
# Timeline of the 2020–2022 China–India skirmishes
# Transnistria conflict
# War in Afghanistan (2001–2021)
# War on terror
# Western DR Congo clashes
# Western Saharan clashes (2020–present)
# Western Togoland Rebellion
# Whisky War
# Yemeni crisis
# Category:2020s military operations
# Category:Conflicts in 2020
# Category:Conflicts in 2021
# Category:Conflicts in 2022
# Category:Conflicts in 2023
# Category:Conflicts in 2024
# Category:Conflicts in 2025
# Category:War in Afghanistan (2001–2021)
# Category:Attacks in the 2020s
# Category:Boko Haram insurgency
# Category:Insurgency in Cabo Delgado
# Category:2020s civil wars
# Category:2020s coups d'état and coup attempts
# Category:War in Darfur
# Category:Ethnic conflicts in Manipur
# Category:Insurgency in Khyber Pakhtunkhwa
# Category:Insurgency in Northeast India
# Category:Internal conflict in Peru
# Category:Iraqi conflict
# Category:Islamic State insurgency in Iraq (2017–present)
# Category:Islamic State–Taliban conflict
# Category:Israel–Hamas war
# Category:Israel–Hezbollah conflict (2023–present)
# Category:Israeli invasion of the Gaza Strip
# Category:Jihadist insurgency in Burkina Faso
# Category:2020s labor disputes and strikes
# Category:Libyan Crisis (2011–present)
# Category:Mexican drug war
# Category:Nagorno-Karabakh conflict
# Category:Naxalite–Maoist insurgency
# Category:Nigerian bandit conflict
# Category:2020s riots
# Category:Russian invasion of Ukraine
# Category:Russo-Ukrainian War
# Category:Somali Civil War (2009–present)
# 44
# 2010 in Russia
# 2011 in Russia
# 2012 in Russia
# 2013 in Russia
# 2014 in Russia
# 2016 in Russia
# 2017 in Russia
# 2018 in Russia
# 2019 in Russia
# Artificial intelligence arms race
# Basmanny Justice
# Fourth-wave Russian emigration
# Great Recession in Russia
# Insurgency in Ingushetia
# Insurgency in Kabardino-Balkaria and Karachay-Cherkessia
# Insurgency in the North Caucasus
# Russia under Vladimir Putin
# Russian involvement in the Syrian civil war
# Russo-Caucasian conflict
# Russo-Ukrainian War
# Category:2010s disestablishments in Russia
# Category:2010s establishments in Russia
# Category:2010 in Russia
# Category:2011 in Russia
# Category:2012 in Russia
# Category:2013 in Russia
# Category:2014 in Russia
# Category:2015 in Russia
# Category:2016 in Russia
# Category:2017 in Russia
# Category:2018 in Russia
# Category:2019 in Russia
# Category:2010s Russian aircraft
# Category:2010s in Russian cinema
# Category:2010s crimes in Russia
# Category:2010s disasters in Russia
# Category:Insurgency in the North Caucasus
# Category:2010s in Kazan
# Category:2010s in Moscow
# Category:2010s in Russian politics
# Category:Russo-Ukrainian War
# Category:2010s in Saint Petersburg
# Category:2010s in Russian sport
# Category:2010s in Russian television
# 40
# 2010 in Ukraine
# 2011 in Ukraine
# 2012 in Ukraine
# 2003 Tuzla Island conflict
# Vulkan files leak
# Zenit oil depot attack
# Category:Annexation of Crimea by the Russian Federation
# Category:Insurgency in the North Caucasus
# Category:Russian invasion of Ukraine
# Category:21st-century Russian military personnel
# Category:Russian involvement in the Syrian civil war
# Category:Russian military intervention in the Syrian civil war
# Category:Russo-Georgian War
# Category:Russo-Ukrainian War
# Category:Second Chechen War
# Category:2003 Tuzla Island conflict
# Category:Wagner Group
# Category:War in Donbas
# 17
# Annexation of Crimea by the Russian Federation
# War in Donbas
# Klintsy oil depot attack
# Omsk refinery attack
# Proletarsk oil depot attack
# Russian invasion of Ukraine
# Russo-Ukrainian War
# 2003 Tuzla Island conflict
# Ukraine and electronic warfare
# Ukrainian involvement in the Iraq War
# Zenit oil depot attack
# Category:Annexation of Crimea by the Russian Federation
# Category:Russian invasion of Ukraine
# Category:Russo-Ukrainian War
# Category:2003 Tuzla Island conflict
# Category:Ukraine in the Iraq War
# Category:War in Donbas
# 671
# ['Naxalite–Maoist insurgency', "Putin's Palace", 'Occupation of Western Armenia', 'Template:Russo-Ukrainian War', 'Environmental impact of the Russian occupation of Crimea', '2012 in Russia', '2020 amendments to the Constitution of Russia', 'Syrian civil war', 'Phone call to Putin', 'Villa Sellgren', 'Russian irredentism', 'Donetsk–Krivoy Rog Soviet Republic', '2015 in Ukraine', 'Russian annexation of Donetsk, Kherson, Luhansk and Zaporizhzhia oblasts', 'Houthi insurgency', 'Islamic State insurgency in Iraq (2017–present)', 'South Thailand insurgency', 'List of international presidential trips made by Petro Poroshenko', 'Transnistria', '2022 Russian debt default', 'Kvartal 95 Studio', 'Central African Republic Civil War', 'List of Black Sea incidents involving Russia and Ukraine', 'Insurgency in Ingushetia', 'Klivazh', 'List of international presidential trips made by Vladimir Putin', '1990 Osh clashes', 'Russian interference in the 2016 United States elections', 'Yelabuga drone factory', '2021 Russia–United States summit', 'Strategic Offensive Reductions Treaty', 'Islamist insurgency in the Sahel', 'Russian Civil War', 'Ukraine Recovery Conference', '2023 Moscow rally', '2017 in Russia', 'Iran–Israel conflict during the Syrian civil war', 'Sypaq Corvo Precision Payload Delivery System', 'Bombing of Tbilisi', 'New START', 'Operation Barbarossa', '2013 in Russia', "Tucker Carlson's interview with Vladimir Putin", 'Saudi-led intervention in the Yemeni civil war', 'Proletarsk oil depot attack', 'Israel–Hezbollah conflict (2023–present)', 'Sudanese civil war (2023–present)', '2022 Russian mobilization', 'December 2021 Russian ultimatum to NATO', 'June 2024 Ukraine peace summit', 'Zenit oil depot attack', 'Fourth-wave Russian emigration', 'Republic of Crimea (Russia)', '2014 in Russia', 'South-East Ukrainian Autonomous Republic', 'Managed nationalism', 'Ruscism', 'Russia national football team results (2020–present)', 'Chechen Revolution', 'Political career of Vladimir Putin', 'Insurgency in the North Caucasus', 'Iran–PJAK conflict', '2024 in Russia', 'Qatar–Saudi Arabia diplomatic conflict', 'Georgian–Ossetian conflict', 'Mobilization in Ukraine', 'U-24 (association)', 'Kremlin drone attack', 'Russian Orbital Service Station', 'COVID-19 pandemic in Russia', 'Allied Democratic Forces insurgency', 'And now I will show you where the attack on Belarus was prepared from', 'Territorial control during the Russo-Ukrainian War', '2008 Russian military reform', 'Alleged doubles of Vladimir Putin', 'Kiev Cossacks insurrection', '2022–2023 Russia–European Union gas dispute', 'List of international prime ministerial trips made by Vladimir Putin', 'List of wars involving Ukraine', 'List of Vladimir Putin legislation and programs', '2010 in Ukraine', '2014 Ukrainian presidential election', '2023 Black Sea drone incident', '2015 Omsk building collapse', 'Polish–Ukrainian War', 'Galician Soviet Socialist Republic', 'Domestic policy of Vladimir Putin', 'Luna 26', 'Russian financial crisis (2014–2016)', 'List of awards and honours received by Vladimir Putin', 'Vulkan files leak', 'United Russia', 'Cabinda War', 'History of the War in Afghanistan (2001–2021)', '2022 Kazakh unrest', 'East Prigorodny conflict', 'Whisky War', 'United24', 'Russian invasion of Ukraine', 'Tajikistani Civil War', 'Pemon conflict', 'Russo-Ukrainian War', 'National Council of Bessarabia', 'List of armed conflicts between Russia and Ukraine', 'Near abroad', 'Russian Fascist Party', 'Bani Walid detention camp', 'Libyan civil war (2014–2020)', 'Nigerian bandit conflict', '2022 Kyrgyzstan–Tajikistan clashes', 'Truth Hounds', 'Vladimir Putin Avenue', 'Black Sea Grain Initiative', 'OSCE Special Monitoring Mission to Ukraine', 'Prelude to the Russian invasion of Ukraine', 'Russian-occupied territories', 'Ukrainian involvement in the Eritrean–Ethiopian War', 'Template:Volodymyr Zelenskyy', 'Libyan crisis (2011–present)', 'Corsican conflict', '2024 Ukrainian coup attempt allegations', ...

# %%
print(len(correctTitles))

save_to_hdfs()
# Out:
# 462

# %%
# Out:
# Fetching batch 1/10...
# Failed to fetch batch 1: [Errno 2] No such file or directory: ''
# Fetching batch 2/10...
# Failed to fetch batch 2: [Errno 2] No such file or directory: ''
# Fetching batch 3/10...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 10
#       8 print(f"Fetching batch {idx}/{len(batches)}...")
#       9 try:
# ---> 10     data = fetch_articles_in_batches(batch)
#      11     processed_data = []
#      12     for page_id, page_info in data["query"]["pages"].items():
#
# Cell In[30], line 37, in fetch_articles_in_batches(titles_batch)
#      28 params = {
#      29     "action": "query",
#      30     "prop": "revisions",
#    (...)
#      34     "titles": "|".join(titles_batch)  # Batch up to 50 titles
#      35 }
#      36 headers = {"User-Agent": "WikiSandbox/ManagingBigData"}
# ---> 37 response = requests.get(url, headers=headers, params=params)
#      38 if response.status_code != 200:
#      39     raise Exception(f"Error fetching articles: {response.status_code}")
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/requests/sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/requests/models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/urllib3/response.py:1063, in HTTPResponse.stream(self, amt, decode_content)
#    1047 """
#    1048 A generator wrapper for the read() method. A call will block until
#    1049 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1060     'content-encoding' header.
#    1061 """
#    1062 if self.chunked and self.supports_chunked_reads():
# -> 1063     yield from self.read_chunked(amt, decode_content=decode_content)
#    1064 else:
#    1065     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/urllib3/response.py:1219, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1216     amt = None
#    1218 while True:
# -> 1219     self._update_chunk_length()
#    1220     if self.chunk_left == 0:
#    1221         break
#
# File ~/wiki/MBD-Wikipedia-Project/.venv/lib/python3.13/site-packages/urllib3/response.py:1138, in HTTPResponse._update_chunk_length(self)
#    1136 if self.chunk_left is not None:
#    1137     return None
# -> 1138 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1139 line = line.split(b";", 1)[0]
#    1140 try:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:
